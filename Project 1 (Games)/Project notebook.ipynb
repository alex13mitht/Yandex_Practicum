# %% [markdown]
# # Введение

# %% [markdown]
# Нам предоставлен Датасет с продажами консольных и ПК игр за большой промежуток времени. задача изучить и дать рекомендации

# %% [markdown]
# ## Знакомимся с данными

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats as st

# %%
#df = pd.read_csv('D:\Карманов\личное\Практикум\проект 5 сборный\games.csv')
df = pd.read_csv('/datasets/games.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
df.columns = df.columns.str.lower()
df.head(10)
# Out:
#                         name platform  year_of_release         genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#    na_sales  eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     41.36     28.96      3.77         8.45          76.0          8      E
# 1     29.08      3.58      6.81         0.77           NaN        NaN    NaN
# 2     15.68     12.76      3.79         3.29          82.0        8.3      E
# 3     15.61     10.93      3.28         2.95          80.0          8      E
# 4     11.27      8.89     10.22         1.00           NaN        NaN    NaN
# 5     23.20      2.26      4.22         0.58           NaN        NaN    NaN
# 6     11.28      9.14      6.50         2.88          89.0        8.5      E
# 7     13.96      9.18      2.93         2.84          58.0        6.6      E
# 8     14.44      6.94      4.70         2.24          87.0        8.4      E
# 9     26.93      0.63      0.28         0.47           NaN        NaN    NaN

# %%
df[df['name'].isna()]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN           1993.0   NaN      1.78      0.53      0.00
# 14244  NaN      GEN           1993.0   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating
# 659           0.08           NaN        NaN    NaN
# 14244         0.00           NaN        NaN    NaN

# %% [markdown]
# Смело этим жертвуем. Пара игр на Мегадрайве, у одной и продаж то нет. какая-нибудь японская дичь видимо была)

# %%
df = df.dropna(subset=['name'])

# %%
df[df['name'].isna()]
# Out:
# Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating]
# Index: []

# %%
df['platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        'PS4', '3DS', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne',
#        'WiiU', 'GC', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
df[df['platform']=='GEN']
# Out:
#                                                     name platform  \
# 145                                 Sonic the Hedgehog 2      GEN
# 257                                   Sonic the Hedgehog      GEN
# 564                                        Mortal Kombat      GEN
# 588                                      Streets of Rage      GEN
# 832                                              NBA Jam      GEN
# 960                                     Sonic & Knuckles      GEN
# 996                                 Sonic the Hedgehog 3      GEN
# 1099        Street Fighter II': Special Champion Edition      GEN
# 1365                              Disney's The Lion King      GEN
# 1453                                     Mortal Kombat 3      GEN
# 1842                          NBA Jam Tournament Edition      GEN
# 6451                                       Virtua Racing      GEN
# 7885                                    Shining Force II      GEN
# 8893                             Super Street Fighter II      GEN
# 9000      Lunar 2: Eternal Blue(sales, but wrong system)      GEN
# 9563                                      Gunstar Heroes      GEN
# 9787                                    Ecco the Dolphin      GEN
# 11563                   Yuu Yuu Hakusho: Makyo Toitsusen      GEN
# 11660                Dragon Slayer: The Legend of Heroes      GEN
# 11986                            Ecco: The Tides of Time      GEN
# 12098  Street Fighter II': Special Champion Edition (...      GEN
# 12264                                  Streets of Rage 3      GEN
# 12984                                    Dynamite Headdy      GEN
# 13343                                       Beyond Oasis      GEN
# 14085                             J-League Pro Striker 2      GEN
# 14132                             Castlevania Bloodlines      GEN
# 14488                            Puzzle & Action: Tant-R      GEN
#
#        year_of_release         genre  na_sales  eu_sales  jp_sales  \
# 145             1992.0      Platform      4.47      1.20      0.16
# 257             1991.0      Platform      3.03      0.91      0.26
# 564             1992.0      Fighting      1.95      0.63      0.00
# 588             1990.0        Action      1.86      0.55      0.11
# 832             1992.0        Sports      1.75      0.25      0.00
# 960             1994.0      Platform      1.24      0.43      0.03
# 996             1994.0      Platform      1.02      0.47      0.20
# 1099            1992.0      Fighting      1.00      0.30      0.31
# 1365            1994.0      Platform      0.97      0.37      0.03
# 1453            1994.0      Fighting      1.03      0.27      0.00
# 1842            1994.0        Sports      0.95      0.14      0.00
# 6451            1994.0        Racing      0.00      0.00      0.26
# 7885            1993.0      Strategy      0.00      0.00      0.19
# 8893            1993.0      Fighting      0.00      0.00      0.15
# 9000            1994.0  Role-Playing      0.00      0.00      0.14
# 9563            1992.0       Shooter      0.00      0.00      0.13
# 9787            1992.0     Adventure      0.00      0.00      0.12
# 11563           1994.0      Fighting      0.00      0.00      0.08
# 11660           1994.0  Role-Playing      0.00      0.00      0.08
# 11986           1993.0     Adventure      0.00      0.00      0.07
# 12098           1993.0        Action      0.00      0.00      0.07
# 12264           1993.0        Action      0.00      0.00      0.07
# 12984           1993.0      Platform      0.00      0.00      0.05
# 13343           1993.0  Role-Playing      0.00      0.00      0.05
# 14085           1994.0        Sports      0.00      0.00      0.04
# 14132           1994.0      Platform      0.00      0.00      0.04
# 14488           1994.0          Misc      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating
# 145           0.19           NaN        NaN    NaN
# 257           0.13           NaN        NaN    NaN
# 564           0.09           NaN        NaN    NaN
# 588           0.08           NaN        NaN    NaN
# 832           0.05           NaN        NaN    NaN
# 960           0.12           NaN        NaN    NaN
# 996           0.07           NaN        NaN    NaN
# 1099          0.04           NaN        NaN    NaN
# 1365          0.05           NaN        NaN    NaN
# 1453          0.04           NaN        NaN    NaN
# 1842          0.03           NaN        NaN    NaN
# 6451          0.00           NaN        NaN    NaN
# 7885          0.00           NaN        NaN    NaN
# 8893          0.00           NaN        NaN    NaN
# 9000          0.00           NaN        NaN    NaN
# 9563          0.00           NaN        NaN    NaN
# 9787          0.00           NaN        NaN    NaN
# 11563         0.00           NaN        NaN    NaN
# 11660         0.00           NaN        NaN    NaN
# 11986         0.00           NaN        NaN    NaN
# 12098         0.00           NaN        NaN    NaN
# 12264         0.00           NaN        NaN    NaN
# 12984         0.00           NaN        NaN    NaN
# 13343         0.00           NaN        NaN    NaN
# 14085         0.00           NaN        NaN    NaN
# 14132         0.00           NaN        NaN    NaN
# 14488         0.00           NaN        NaN    NaN

# %% [markdown]
# Смущает меня эта выборка:
#
# Соник 2 в Америке 4,5 млн , 1,2 в европе и всего 160 тычсяч у себя на родине?
#
# Beyond Oasis - по нулям в Европе и Америке, но при этом есть продажи в Японии??? это же европейское название игры. в японии она называлась The story of Thor! и вышла она в японии в 94-м, а в европе и америке в 95-м, но никак не в 93-м

# %%
df[df['name'].str.contains('Sonic Adventure')]
# Out:
#                                     name platform  year_of_release     genre  \
# 601             Sonic Adventure 2 Battle       GC           2001.0  Platform
# 643                      Sonic Adventure       DC           1998.0  Platform
# 1565  Sonic Adventure DX: Director's Cut       GC           2003.0  Platform
# 9844                   Sonic Adventure 2       DC           2001.0  Platform
#
#       na_sales  eu_sales  jp_sales  other_sales  critic_score user_score  \
# 601       1.70      0.59      0.21         0.07          73.0        8.3
# 643       1.26      0.61      0.46         0.08           NaN        NaN
# 1565      0.87      0.30      0.06         0.03          57.0        7.9
# 9844      0.00      0.00      0.12         0.00          89.0        8.6
#
#      rating
# 601       E
# 643     NaN
# 1565      E
# 9844      E

# %% [markdown]
# второй Адвенчур ни в Европе ни в Америке на Дримкасте не продался?..
# <a href="https://ru.wikibrief.org/wiki/Sonic_Adventure_2#:~:text=Sonic%20Adventure%202%20Battle%20%D1%82%D0%B0%D0%BA%D0%B6%D0%B5,%D0%B4%D0%BB%D1%8F%20%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D0%B9%20Dreamcast%20%D0%B8%20GameCube">Ссылка</a>.
# судя по этому сайту итого продаж примерно то-же количество, но вот распределение не то
#
# и где версия для ПК и для ящика 360?

# %%
df[(df['rating'].isna())&(~df['year_of_release'].isna())].sort_values('year_of_release').tail(20)
# Out:
#                                                     name platform  \
# 15814                                       Koihime Enbu      PS4
# 8022                  Jikkyou Powerful Pro Baseball 2016      PSV
# 15790                                   This War of Mine      PS4
# 15782                       Taishou Moebius Line Vitable      PSV
# 8282                  Jikkyou Powerful Pro Baseball 2016      PS4
# 15748            Revolution: 25th Anniversary Collection       PC
# 8611                                       Yakuza Kiwami      PS4
# 7769                                       Kan Colle Kai      PSV
# 15678  Moshi, Kono Sekai ni Kami-sama ga Iru to suru ...      PSV
# 15627                                             Uppers      PSV
# 15624                     Coven and Labyrinth of Refrain      PSV
# 15620  TV Anime Idolm@ster: Cinderella Girls G4U! Pac...      PS3
# 15599                                Winning Post 8 2016      PS4
# 9350                              Attack on Titan (KOEI)      PSV
# 9360   Dragon Quest Heroes II: Twin Kings and the Pro...      PS3
# 15563                                 Resident Evil 5 HD     XOne
# 9685                               F1 2016 (Codemasters)     XOne
# 15489                   Agatha Christie: The ABC Murders       PC
# 15646     Nil Admirari no Tenbin: Teito Genwaku Toukidan      PSV
# 16714                                Winning Post 8 2016      PSV
#
#        year_of_release       genre  na_sales  eu_sales  jp_sales  other_sales  \
# 15814           2016.0    Fighting      0.00      0.00      0.02         0.00
# 8022            2016.0      Sports      0.00      0.00      0.18         0.00
# 15790           2016.0      Action      0.00      0.01      0.00         0.00
# 15782           2016.0   Adventure      0.00      0.00      0.02         0.00
# 8282            2016.0      Sports      0.00      0.00      0.17         0.00
# 15748           2016.0   Adventure      0.00      0.02      0.00         0.00
# 8611            2016.0   Adventure      0.00      0.00      0.16         0.00
# 7769            2016.0      Action      0.00      0.00      0.19         0.00
# 15678           2016.0   Adventure      0.00      0.00      0.02         0.00
# 15627           2016.0      Action      0.00      0.00      0.02         0.00
# 15624           2016.0      Action      0.00      0.00      0.02         0.00
# 15620           2016.0        Misc      0.00      0.00      0.02         0.00
# 15599           2016.0  Simulation      0.00      0.00      0.02         0.00
# 9350            2016.0      Action      0.00      0.00      0.13         0.00
# 9360            2016.0      Action      0.00      0.00      0.13         0.00
# 15563           2016.0      Action      0.02      0.00      0.00         0.00
# 9685            2016.0      Racing      0.03      0.08      0.00         0.01
# 15489           2016.0   Adventure      0.00      0.02      0.00         0.00
# 15646           2016.0   Adventure      0.00      0.00      0.02         0.00
# 16714           2016.0  Simulation      0.00      0.00      0.01         0.00
#
#        critic_score user_score rating
# 15814           NaN        NaN    NaN
# 8022            NaN        NaN    NaN
# 15790           NaN        NaN    NaN
# 15782           NaN        NaN    NaN
# 8282            NaN        NaN    NaN
# 15748           NaN        tbd    NaN
# 8611            NaN        NaN    NaN
# 7769            NaN        NaN    NaN
# 15678           NaN        NaN    NaN
# 15627           NaN        NaN    NaN
# 15624           NaN        NaN    NaN
# 15620           NaN        NaN    NaN
# 15599           NaN        NaN    NaN
# 9350            NaN        NaN    NaN
# 9360            NaN        NaN    NaN
# 15563           NaN        NaN    NaN
# 9685            NaN        NaN    NaN
# 15489          66.0        8.5    NaN
# 15646           NaN        NaN    NaN
# 16714           NaN        NaN    NaN

# %%
df[df['name'].str.contains('Resident Evil')]
# Out:
#                                 name platform  year_of_release    genre  \
# 151                  Resident Evil 2       PS           1998.0   Action
# 199                  Resident Evil 5      PS3           2009.0   Action
# 203                    Resident Evil       PS           1996.0   Action
# 327     Resident Evil Director's Cut       PS           1996.0   Action
# 334         Resident Evil 3: Nemesis       PS           1999.0   Action
# ...                              ...      ...              ...      ...
# 14871             Resident Evil 5 HD      PS4           2016.0   Action
# 15148  Resident Evil: Umbrella Corps      PS4           2016.0   Action
# 15371             Resident Evil Zero       PC           2016.0   Action
# 15467             Resident Evil 4 HD     XOne           2016.0  Shooter
# 15563             Resident Evil 5 HD     XOne           2016.0   Action
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score user_score  \
# 151        1.88      1.47      2.02         0.45          89.0        9.2
# 199        1.96      1.41      1.08         0.64          84.0        7.5
# 203        2.05      1.16      1.11         0.73          91.0          9
# 327        1.82      1.24      0.47         0.25           NaN        NaN
# 334        1.30      0.77      1.54         0.11           NaN        NaN
# ...         ...       ...       ...          ...           ...        ...
# 14871      0.02      0.00      0.00         0.01           NaN        NaN
# 15148      0.00      0.00      0.02         0.00           NaN        NaN
# 15371      0.01      0.01      0.00         0.00           NaN        NaN
# 15467      0.02      0.00      0.00         0.00           NaN        NaN
# 15563      0.02      0.00      0.00         0.00           NaN        NaN
#
#       rating
# 151        M
# 199        M
# 203        M
# 327      NaN
# 334      NaN
# ...      ...
# 14871    NaN
# 15148    NaN
# 15371    NaN
# 15467    NaN
# 15563    NaN
#
# [61 rows x 11 columns]

# %%
df[(df['name'].str.contains('Resident Evil'))&(df['year_of_release']!=2016)].sort_values('year_of_release')
# Out:
#                                                    name platform  \
# 203                                       Resident Evil       PS
# 327                        Resident Evil Director's Cut       PS
# 8448                                      Resident Evil      SAT
# 8287   Resident Evil Director's Cut: Dual Shock Edition       PS
# 151                                     Resident Evil 2       PS
# 6258                Resident Evil 2: Dual Shock Edition       PS
# 3585                                    Resident Evil 2      N64
# 334                            Resident Evil 3: Nemesis       PS
# 2869                            Resident Evil: Survivor       PS
# 1787                     Resident Evil - Code: Veronica       DC
# 679                    Resident Evil - Code: Veronica X      PS2
# 1359                             Resident Evil (Remake)       GC
# 1521                                 Resident Evil Zero       GC
# 12621                  Resident Evil - Code: Veronica X       GC
# 12705                                   Resident Evil 2       GC
# 5296                            Resident Evil: Dead Aim      PS2
# 1316                            Resident Evil: Outbreak      PS2
# 11674                          Resident Evil 3: Nemesis       GC
# 3540                     Resident Evil Outbreak File #2      PS2
# 350                                     Resident Evil 4      PS2
# 1068                                    Resident Evil 4       GC
# 9647                                      Resident Evil      PS3
# 13453                      Resident Evil Director's Cut      PS3
# 6555                      Resident Evil: Deadly Silence       DS
# 14656                                   Resident Evil 4       PC
# 732                                     Resident Evil 4      Wii
# 1228             Resident Evil: The Umbrella Chronicles      Wii
# 5895              Resident Evil Archives: Resident Evil      Wii
# 6890         Resident Evil Archives: Resident Evil Zero      Wii
# 199                                     Resident Evil 5      PS3
# 375                                     Resident Evil 5     X360
# 1966             Resident Evil: The Darkside Chronicles      Wii
# 12199                                   Resident Evil 5       PC
# 4039                  Resident Evil: The Mercenaries 3D      3DS
# 13894             Resident Evil: Operation Raccoon City       PC
# 13675                                   Resident Evil 6       PC
# 449                                     Resident Evil 6      PS3
# 10962                       Resident Evil Chronicles HD      PS3
# 874                                     Resident Evil 6     X360
# 1721              Resident Evil: Operation Raccoon City      PS3
# 2368                         Resident Evil: Revelations      3DS
# 2654              Resident Evil: Operation Raccoon City     X360
# 2762                         Resident Evil: Revelations      PS3
# 7876                         Resident Evil: Revelations     WiiU
# 6544                         Resident Evil: Revelations     X360
# 13841                        Resident Evil: Revelations       PC
# 10620                      Resident Evil: Revelations 2     XOne
# 12005                      Resident Evil: Revelations 2     X360
# 6013                       Resident Evil: Revelations 2      PS3
# 10605                      Resident Evil: Revelations 2      PSV
# 3645                       Resident Evil: Revelations 2      PS4
#
#        year_of_release    genre  na_sales  eu_sales  jp_sales  other_sales  \
# 203             1996.0   Action      2.05      1.16      1.11         0.73
# 327             1996.0   Action      1.82      1.24      0.47         0.25
# 8448            1997.0   Action      0.00      0.00      0.17         0.00
# 8287            1997.0   Action      0.00      0.00      0.16         0.01
# 151             1998.0   Action      1.88      1.47      2.02         0.45
# 6258            1998.0   Action      0.00      0.00      0.26         0.02
# 3585            1999.0   Action      0.39      0.09      0.07         0.01
# 334             1999.0   Action      1.30      0.77      1.54         0.11
# 2869            2000.0   Action      0.23      0.15      0.29         0.05
# 1787            2000.0   Action      0.41      0.23      0.47         0.03
# 679             2001.0   Action      1.08      0.70      0.34         0.21
# 1359            2002.0   Action      0.63      0.38      0.35         0.05
# 1521            2002.0   Action      0.54      0.27      0.45         0.04
# 12621           2003.0   Action      0.05      0.01      0.00         0.00
# 12705           2003.0   Action      0.04      0.01      0.00         0.00
# 5296            2003.0   Action      0.17      0.13      0.00         0.04
# 1316            2003.0   Action      0.54      0.35      0.46         0.10
# 11674           2003.0   Action      0.06      0.02      0.00         0.00
# 3540            2004.0   Action      0.19      0.15      0.17         0.05
# 350             2005.0   Action      2.08      0.83      0.46         0.25
# 1068            2005.0   Action      0.98      0.42      0.22         0.06
# 9647            2006.0   Action      0.00      0.00      0.12         0.00
# 13453           2006.0   Action      0.00      0.00      0.05         0.00
# 6555            2006.0   Action      0.11      0.02      0.11         0.01
# 14656           2007.0   Action      0.00      0.02      0.00         0.00
# 732             2007.0   Action      1.32      0.56      0.14         0.20
# 1228            2007.0   Action      0.67      0.43      0.29         0.14
# 5895            2008.0   Action      0.16      0.04      0.08         0.02
# 6890            2008.0   Action      0.13      0.03      0.06         0.01
# 199             2009.0   Action      1.96      1.41      1.08         0.64
# 375             2009.0   Action      2.11      0.93      0.12         0.34
# 1966            2009.0   Action      0.46      0.31      0.20         0.09
# 12199           2009.0   Action      0.01      0.04      0.00         0.01
# 4039            2011.0   Action      0.16      0.16      0.13         0.03
# 13894           2012.0   Action      0.00      0.03      0.00         0.01
# 13675           2012.0  Shooter      0.00      0.04      0.00         0.00
# 449             2012.0  Shooter      0.88      0.94      0.88         0.40
# 10962           2012.0  Shooter      0.00      0.00      0.09         0.00
# 874             2012.0  Shooter      1.12      0.60      0.07         0.16
# 1721            2012.0   Action      0.48      0.24      0.36         0.10
# 2368            2012.0   Action      0.30      0.22      0.30         0.05
# 2654            2012.0   Action      0.55      0.14      0.03         0.06
# 2762            2013.0   Action      0.14      0.29      0.22         0.09
# 7876            2013.0   Action      0.07      0.07      0.03         0.01
# 6544            2013.0   Action      0.12      0.10      0.02         0.02
# 13841           2013.0   Action      0.00      0.04      0.00         0.00
# 10620           2015.0   Action      0.07      0.02      0.00         0.01
# 12005           2015.0   Action      0.04      0.02      0.00         0.01
# 6013            2015.0   Action      0.06      0.05      0.16         0.02
# 10605           2015.0   Action      0.00      0.03      0.07         0.01
# 3645            2015.0   Action      0.13      0.24      0.10         0.07
#
#        critic_score user_score rating
# 203            91.0          9      M
# 327             NaN        NaN    NaN
# 8448            NaN        NaN    NaN
# 8287            NaN        NaN    NaN
# 151            89.0        9.2      M
# 6258            NaN        NaN    NaN
# 3585            NaN        NaN    NaN
# 334             NaN        NaN    NaN
# 2869           39.0          7      M
# 1787            NaN        NaN    NaN
# 679            84.0        8.4      M
# 1359            NaN        NaN    NaN
# 1521            NaN        NaN    NaN
# 12621          62.0        8.5      M
# 12705          59.0        8.5      M
# 5296           65.0        6.6      M
# 1316           71.0        8.3      M
# 11674          62.0        8.3      M
# 3540           58.0        7.7      M
# 350            96.0        8.9      M
# 1068           96.0        9.4      M
# 9647            NaN        NaN    NaN
# 13453           NaN        NaN    NaN
# 6555           71.0        8.4      M
# 14656          76.0        7.4      M
# 732             NaN        NaN    NaN
# 1228           75.0        7.6      M
# 5895           76.0        8.9      M
# 6890           62.0        8.2      M
# 199            84.0        7.5      M
# 375            83.0        7.5      M
# 1966           75.0          8      M
# 12199          86.0        7.1      M
# 4039           65.0        6.4      M
# 13894          48.0        3.8      M
# 13675          69.0        5.9      M
# 449            74.0        5.4      M
# 10962           NaN        NaN    NaN
# 874            67.0          5      M
# 1721           52.0        4.9      M
# 2368           82.0        8.5      M
# 2654           52.0        4.9      M
# 2762           74.0        7.2      M
# 7876           80.0        7.5      M
# 6544           75.0        7.4      M
# 13841          77.0          7      M
# 10620          75.0        7.5      M
# 12005           NaN        6.6      M
# 6013            NaN        6.8      M
# 10605          65.0        7.8      M
# 3645           75.0        7.7      M

# %%
df[(df['name'].str.contains('biohazard', case=False))]
# Out:
#                                name platform  year_of_release   genre  \
# 8172   Biohazard: Revival Selection      PS3           2011.0  Action
# 14766  Biohazard: Revival Selection     X360           2011.0  Action
# 15734   Prototype: Biohazard Bundle      PS4           2016.0  Action
# 16314   Prototype: Biohazard Bundle     XOne           2016.0  Action
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score user_score  \
# 8172       0.00       0.0      0.18          0.0           NaN        NaN
# 14766      0.00       0.0      0.03          0.0           NaN        NaN
# 15734      0.01       0.0      0.00          0.0          48.0          2
# 16314      0.01       0.0      0.00          0.0          56.0        3.1
#
#       rating
# 8172     NaN
# 14766    NaN
# 15734      M
# 16314      M

# %% [markdown]
# вопросов к Рейтингу все больше.
#
# 1) понятно, что ESRB - Американская рейтинговая компания, и релизы для Европы (PEGI) тут не отмечены, а уж японии так тем более. Но если Японскую дичь можно вычислить по названию, то как определить, что релиз Европейский?
#
# 2) понятно, что игры до формирования ESRB не могут обладать этим рейтингом. это логично.
#
# 3) допустим игры 2016 года еще рейтинг не получили (хотя при этом успели продаться)
#
# 4) но вот почему несколько Резидентов в 2000-х не обладают рейтингом? хоть и по продажам это похоже на японский рынок, но там серия игр называется BioHazard вроде, а их в этом датасете нет

# %% [markdown]
# ## обработка данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16713 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16444 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.5+ MB

# %% [markdown]
# название столбцов уже приведено к нужному регистру. удалены 2 игры, в которых ничего кроме данных о продажах нет (даже имени)

# %%
df[['name','year_of_release', 'platform']].duplicated().sum()
# Out:
# 1

# %%
df[df[['name','year_of_release', 'platform']].duplicated()]
# Out:
#                 name platform  year_of_release   genre  na_sales  eu_sales  \
# 16230  Madden NFL 13      PS3           2012.0  Sports       0.0      0.01
#
#        jp_sales  other_sales  critic_score user_score rating
# 16230       0.0          0.0          83.0        5.5      E

# %%
df[df['name']=='Madden NFL 13']
# Out:
#                 name platform  year_of_release   genre  na_sales  eu_sales  \
# 507    Madden NFL 13     X360           2012.0  Sports      2.53      0.15
# 604    Madden NFL 13      PS3           2012.0  Sports      2.11      0.22
# 3986   Madden NFL 13      Wii           2012.0  Sports      0.47      0.00
# 5887   Madden NFL 13      PSV           2012.0  Sports      0.28      0.00
# 7066   Madden NFL 13     WiiU           2012.0  Sports      0.21      0.00
# 16230  Madden NFL 13      PS3           2012.0  Sports      0.00      0.01
#
#        jp_sales  other_sales  critic_score user_score rating
# 507         0.0         0.17          81.0        5.8      E
# 604         0.0         0.23          83.0        5.5      E
# 3986        0.0         0.03           NaN        7.3      E
# 5887        0.0         0.02          63.0        7.3      E
# 7066        0.0         0.02          75.0        6.7      E
# 16230       0.0         0.00          83.0        5.5      E

# %% [markdown]
# подправим данные футбола под 604 индексом, а 16230 удалим

# %%
df.loc[604, 'eu_sales']=0.23
df[df['name']=='Madden NFL 13']
# Out:
#                 name platform  year_of_release   genre  na_sales  eu_sales  \
# 507    Madden NFL 13     X360           2012.0  Sports      2.53      0.15
# 604    Madden NFL 13      PS3           2012.0  Sports      2.11      0.23
# 3986   Madden NFL 13      Wii           2012.0  Sports      0.47      0.00
# 5887   Madden NFL 13      PSV           2012.0  Sports      0.28      0.00
# 7066   Madden NFL 13     WiiU           2012.0  Sports      0.21      0.00
# 16230  Madden NFL 13      PS3           2012.0  Sports      0.00      0.01
#
#        jp_sales  other_sales  critic_score user_score rating
# 507         0.0         0.17          81.0        5.8      E
# 604         0.0         0.23          83.0        5.5      E
# 3986        0.0         0.03           NaN        7.3      E
# 5887        0.0         0.02          63.0        7.3      E
# 7066        0.0         0.02          75.0        6.7      E
# 16230       0.0         0.00          83.0        5.5      E

# %%
df = df.drop([16230])

# %%
df[df['name']=='Madden NFL 13']
# Out:
#                name platform  year_of_release   genre  na_sales  eu_sales  \
# 507   Madden NFL 13     X360           2012.0  Sports      2.53      0.15
# 604   Madden NFL 13      PS3           2012.0  Sports      2.11      0.23
# 3986  Madden NFL 13      Wii           2012.0  Sports      0.47      0.00
# 5887  Madden NFL 13      PSV           2012.0  Sports      0.28      0.00
# 7066  Madden NFL 13     WiiU           2012.0  Sports      0.21      0.00
#
#       jp_sales  other_sales  critic_score user_score rating
# 507        0.0         0.17          81.0        5.8      E
# 604        0.0         0.23          83.0        5.5      E
# 3986       0.0         0.03           NaN        7.3      E
# 5887       0.0         0.02          63.0        7.3      E
# 7066       0.0         0.02          75.0        6.7      E

# %%
df_pegi = pd.read_json('https://raw.githubusercontent.com/ashjames/Pegi-dataset/master/snapshot/1999-to-2019-01-12/all_30183.json')

# %%
df_pegi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30183 entries, 0 to 30182
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Title                 30183 non-null  object
#  1   Title Description     8767 non-null   object
#  2   Descriptor Image URL  30183 non-null  object
#  3   Rating                30183 non-null  int64
#  4   Rating Image URL      30183 non-null  object
#  5   Platform              30183 non-null  object
#  6   Release Date          30183 non-null  object
#  7   Publisher             30183 non-null  object
#  8   Publisher URL         0 non-null      float64
#  9   Consumer Advice       8774 non-null   object
#  10  Descriptor            30183 non-null  object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 2.5+ MB

# %%
df['name'].isin(df_pegi['Title']).sum()
# Out:
# 5091

# %% [markdown]
# Добавлю для наглядности колонку с Pegi рейтингом. Cero мне не удалось быстро найти в доступе
#
#
# Спустя пару часов:
#
# А не так просто скрестить эти таблицы - например Super Mario Bros. в нашем датасете 85-го года выпуска c Денди, а в ПЕГИ 2011 на 3ds
#
# придется перед этим дату подправить

# %%
df_pegi.columns = df_pegi.columns.str.replace('Title', 'name')
df_pegi.columns = df_pegi.columns.str.replace('Rating', 'pegi_rating')

df_pegi['Release Date'] = df_pegi['Release Date'].str.replace('0018-06-15', '2018-06-15')

df_pegi['date'] = pd.to_datetime(df_pegi['Release Date'], format='%Y-%m-%d %H:%M:%S')

# %%
df_pegi['year_of_release'] = pd. DatetimeIndex(df_pegi['date']).year

# %%
df_pegi = df_pegi[['name','pegi_rating','year_of_release']]
df_pegi = df_pegi.drop_duplicates()

# %%
df_pegi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22108 entries, 0 to 30182
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             22108 non-null  object
#  1   pegi_rating      22108 non-null  int64
#  2   year_of_release  22108 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 690.9+ KB

# %% [markdown]
# поскольку нас интересует анализ по определенным годам, то заполним пропуска 3000м годом. использовать срение/медианы тут точно не к месту, искать релиз по другим источникам вручную -  очень трудозатратно

# %%
#df['year_of_release'] = df['year_of_release'].fillna(3000).astype('int64')

# %% [markdown]
# Это оказалось неверным решением при анализе по платформам. попробуем для каждой платформы выбрать медианный год

# %%
plat_year = df.pivot_table(index = 'platform', values = 'year_of_release', aggfunc='median')
plat_year
# Out:
#           year_of_release
# platform
# 2600               1982.0
# 3DO                1995.0
# 3DS                2013.0
# DC                 2000.0
# DS                 2008.0
# GB                 1997.0
# GBA                2003.0
# GC                 2003.0
# GEN                1993.0
# GG                 1992.0
# N64                1999.0
# NES                1986.5
# NG                 1994.5
# PC                 2010.0
# PCFX               1996.0
# PS                 1998.0
# PS2                2005.0
# PS3                2011.0
# PS4                2015.0
# PSP                2009.0
# PSV                2014.0
# SAT                1996.0
# SCD                1994.0
# SNES               1994.0
# TG16               1995.0
# WS                 2000.0
# Wii                2009.0
# WiiU               2013.0
# X360               2010.0
# XB                 2004.0
# XOne               2015.0

# %%
plat_year.loc['PS','year_of_release']
# Out:
# 1998.0

# %% [markdown]
# Осталось подготовить функцию для строки.

# %%
def fill_year(row):
    if pd.isna(row['year_of_release']):
        #print(row['platform'],plat_year.loc[row['platform'],'year_of_release'] )
        return plat_year.loc[row['platform'],'year_of_release']
    else:
        #print('хрен')
        return row['year_of_release']

# %%
df = df.dropna(subset=['year_of_release'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16443 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16443 non-null  object
#  1   platform         16443 non-null  object
#  2   year_of_release  16443 non-null  float64
#  3   genre            16443 non-null  object
#  4   na_sales         16443 non-null  float64
#  5   eu_sales         16443 non-null  float64
#  6   jp_sales         16443 non-null  float64
#  7   other_sales      16443 non-null  float64
#  8   critic_score     7982 non-null   float64
#  9   user_score       9838 non-null   object
#  10  rating           9767 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.5+ MB

# %%
df = df.merge(df_pegi, on = ['name','year_of_release'], how='left')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16573 entries, 0 to 16572
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16573 non-null  object
#  1   platform         16573 non-null  object
#  2   year_of_release  16573 non-null  float64
#  3   genre            16573 non-null  object
#  4   na_sales         16573 non-null  float64
#  5   eu_sales         16573 non-null  float64
#  6   jp_sales         16573 non-null  float64
#  7   other_sales      16573 non-null  float64
#  8   critic_score     8094 non-null   float64
#  9   user_score       9958 non-null   object
#  10  rating           9887 non-null   object
#  11  pegi_rating      3580 non-null   float64
# dtypes: float64(7), object(5)
# memory usage: 1.6+ MB

# %% [markdown]
# Откуда 130 лишних строчек?

# %%
df[(df['rating'].isna())&(~df['pegi_rating'].isna())]
# Out:
#                                             name platform  year_of_release  \
# 112                    Mario Kart: Double Dash!!       GC           2003.0
# 122                                      FIFA 12      PS3           2011.0
# 197           Mario & Sonic at the Olympic Games       DS           2008.0
# 236    Mario & Sonic at the Olympic Winter Games      Wii           2009.0
# 278                                      FIFA 12     X360           2011.0
# ...                                          ...      ...              ...
# 16518                           Prison Architect     XOne           2016.0
# 16534                           G1 Jockey 4 2008      PS3           2008.0
# 16548                             Pony Friends 2       PC           2009.0
# 16563                                    15 Days       PC           2009.0
# 16569                           LMA Manager 2007     X360           2006.0
#
#             genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 112        Racing      4.12      1.77      0.87         0.19           NaN
# 122        Sports      0.84      4.30      0.11         1.39           NaN
# 197        Sports      1.63      2.45      0.44         0.57           NaN
# 236        Sports      1.87      1.96      0.22         0.48           NaN
# 278        Sports      0.84      2.78      0.02         0.53           NaN
# ...           ...       ...       ...       ...          ...           ...
# 16518      Action      0.01      0.00      0.00         0.00          74.0
# 16534      Sports      0.00      0.00      0.00         0.00           NaN
# 16548  Simulation      0.00      0.01      0.00         0.00           NaN
# 16563   Adventure      0.00      0.01      0.00         0.00          63.0
# 16569      Sports      0.00      0.01      0.00         0.00           NaN
#
#       user_score rating  pegi_rating
# 112          NaN    NaN          3.0
# 122          NaN    NaN          3.0
# 197          NaN    NaN          3.0
# 236          NaN    NaN          3.0
# 278          NaN    NaN          3.0
# ...          ...    ...          ...
# 16518        6.7    NaN         16.0
# 16534        NaN    NaN          3.0
# 16548        NaN    NaN          3.0
# 16563        5.8    NaN         16.0
# 16569        NaN    NaN          3.0
#
# [354 rows x 12 columns]

# %% [markdown]
# попробуем найти

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[['name','year_of_release', 'platform']].duplicated().sum()
# Out:
# 130

# %% [markdown]
# а вот и они. нужно посмотреть что в них появилось разного при сборе таблицы и удалить ненужные дубликаты.

# %%
df['name'].isin(df[df[['name','year_of_release', 'platform']].duplicated()]['name']).sum()
# Out:
# 263

# %%
df[df['name'].isin(df[df[['name','year_of_release', 'platform']].duplicated()]['name'])]
# Out:
#                               name platform  year_of_release         genre  \
# 85                      The Sims 3       PC           2009.0    Simulation
# 252    Need for Speed: Most Wanted      PS2           2005.0        Racing
# 253    Need for Speed: Most Wanted      PS2           2005.0        Racing
# 390                   Spider-Man 2      PS2           2004.0        Action
# 391                   Spider-Man 2      PS2           2004.0        Action
# ...                            ...      ...              ...           ...
# 14750              Schlag den Raab       PC           2010.0          Misc
# 14751              Schlag den Raab       PC           2010.0          Misc
# 15131          Tom Clancy's EndWar       PC           2009.0      Strategy
# 16198    Marvel: Ultimate Alliance       PC           2006.0  Role-Playing
# 16199    Marvel: Ultimate Alliance       PC           2006.0  Role-Playing
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score user_score  \
# 85         0.99      6.42      0.00         0.60          86.0        7.6
# 252        2.03      1.79      0.08         0.47          82.0        9.1
# 253        2.03      1.79      0.08         0.47          82.0        9.1
# 390        1.75      1.20      0.02         0.43          80.0        8.9
# 391        1.75      1.20      0.02         0.43          80.0        8.9
# ...         ...       ...       ...          ...           ...        ...
# 14750      0.00      0.02      0.00         0.00           NaN        NaN
# 14751      0.00      0.02      0.00         0.00           NaN        NaN
# 15131      0.00      0.02      0.00         0.00          68.0        6.7
# 16198      0.01      0.00      0.00         0.00          82.0          8
# 16199      0.01      0.00      0.00         0.00          82.0          8
#
#       rating  pegi_rating
# 85         T         12.0
# 252        T          3.0
# 253        T         12.0
# 390        T          3.0
# 391        T          7.0
# ...      ...          ...
# 14750    NaN          3.0
# 14751    NaN         12.0
# 15131      T         16.0
# 16198      T          7.0
# 16199      T         12.0
#
# [263 rows x 12 columns]

# %% [markdown]
# ага, разный ПЕГИ рейтинг. он появился из-за какого-то пропущенного условия при склеивании столбцов (например платформу я не учитывал, так как формат представления отличается). дубликаты до пеги рейтинга смело удаляем. Наш рейтинг ESRB, Pegi только для ориентира

# %%
df =df.drop(df[df[['name','year_of_release', 'platform','genre','rating']].duplicated()].index)

# %%
df[['name','year_of_release', 'platform']].duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16443 entries, 0 to 16572
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16443 non-null  object
#  1   platform         16443 non-null  object
#  2   year_of_release  16443 non-null  float64
#  3   genre            16443 non-null  object
#  4   na_sales         16443 non-null  float64
#  5   eu_sales         16443 non-null  float64
#  6   jp_sales         16443 non-null  float64
#  7   other_sales      16443 non-null  float64
#  8   critic_score     7982 non-null   float64
#  9   user_score       9838 non-null   object
#  10  rating           9767 non-null   object
#  11  pegi_rating      3450 non-null   float64
# dtypes: float64(7), object(5)
# memory usage: 1.6+ MB

# %% [markdown]
# Заполнять Оценки точно не стоит, наведет на неверные выводы. в современном мире уже сколько раз были ситуации, что от критиков оценка просто проплачена, плохая оценка пользователей удалена, а продажи и вохвраты говорят сами за себя (привет Киберпанку). рэйтинг туда же.

# %% [markdown]
# теперь user score TBD - To be define - будет определено

# %%
df[df['user_score']=='tbd']
# Out:
#                                  name platform  year_of_release       genre  \
# 119                     Zumba Fitness      Wii           2010.0      Sports
# 301    Namco Museum: 50th Anniversary      PS2           2005.0        Misc
# 519                   Zumba Fitness 2      Wii           2011.0      Sports
# 644                      uDraw Studio      Wii           2010.0        Misc
# 716                   Just Dance Kids      Wii           2010.0        Misc
# ...                               ...      ...              ...         ...
# 16553                 Planet Monsters      GBA           2001.0      Action
# 16555                Bust-A-Move 3000       GC           2003.0      Puzzle
# 16556                Mega Brain Boost       DS           2008.0      Puzzle
# 16562                        Plushees       DS           2008.0  Simulation
# 16564   Men in Black II: Alien Escape       GC           2003.0     Shooter
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score user_score  \
# 119        3.45      2.59       0.0         0.66           NaN        tbd
# 301        2.08      1.35       0.0         0.54          61.0        tbd
# 519        1.51      1.03       0.0         0.27           NaN        tbd
# 644        1.65      0.57       0.0         0.20          71.0        tbd
# 716        1.52      0.54       0.0         0.18           NaN        tbd
# ...         ...       ...       ...          ...           ...        ...
# 16553      0.01      0.00       0.0         0.00          67.0        tbd
# 16555      0.01      0.00       0.0         0.00          53.0        tbd
# 16556      0.01      0.00       0.0         0.00          48.0        tbd
# 16562      0.01      0.00       0.0         0.00           NaN        tbd
# 16564      0.01      0.00       0.0         0.00           NaN        tbd
#
#       rating  pegi_rating
# 119        E          NaN
# 301     E10+          NaN
# 519        T          NaN
# 644        E          3.0
# 716        E          NaN
# ...      ...          ...
# 16553      E          NaN
# 16555      E          NaN
# 16556      E          NaN
# 16562      E          NaN
# 16564      T          NaN
#
# [2376 rows x 12 columns]

# %% [markdown]
# я бы понял для новинок такое заполнение. я заменю наа NaN, чтобы и не мешало в рассчетах и не вносило корректировки

# %%
df['user_score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %%
df = df.replace('tbd', np.nan)

# %%
df[df['user_score']=='tbd']
# Out:
# Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating, pegi_rating]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16443 entries, 0 to 16572
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16443 non-null  object
#  1   platform         16443 non-null  object
#  2   year_of_release  16443 non-null  float64
#  3   genre            16443 non-null  object
#  4   na_sales         16443 non-null  float64
#  5   eu_sales         16443 non-null  float64
#  6   jp_sales         16443 non-null  float64
#  7   other_sales      16443 non-null  float64
#  8   critic_score     7982 non-null   float64
#  9   user_score       7462 non-null   object
#  10  rating           9767 non-null   object
#  11  pegi_rating      3450 non-null   float64
# dtypes: float64(7), object(5)
# memory usage: 1.6+ MB

# %% [markdown]
# а вот теперь и тип данных подменим

# %%
df['user_score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', '8.8', '6.9', '9.4', '6.8', '6.1',
#        '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6', '3.7',
#        '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9', '3.1',
#        '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3', '2.7',
#        '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0', '1.6',
#        '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2', '2.3',
#        '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'], dtype=object)

# %%
df['user_score'] = df['user_score'].astype('float64')

# %%
df = df.astype({'year_of_release': 'int32',
                'na_sales': 'float32',
                'eu_sales': 'float32',
                'jp_sales': 'float32',
                'other_sales': 'float32',
                'pegi_rating': 'float32',
               })

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16443 entries, 0 to 16572
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16443 non-null  object
#  1   platform         16443 non-null  object
#  2   year_of_release  16443 non-null  int32
#  3   genre            16443 non-null  object
#  4   na_sales         16443 non-null  float32
#  5   eu_sales         16443 non-null  float32
#  6   jp_sales         16443 non-null  float32
#  7   other_sales      16443 non-null  float32
#  8   critic_score     7982 non-null   float64
#  9   user_score       7462 non-null   float64
#  10  rating           9767 non-null   object
#  11  pegi_rating      3450 non-null   float32
# dtypes: float32(5), float64(2), int32(1), object(4)
# memory usage: 1.3+ MB

# %%
df['all_sales']=df['eu_sales']+df['na_sales']+df['jp_sales']+df['other_sales']

# %%
df[(df['year_of_release']==1985)&(df['platform']=='DS')]
# Out:
#                                       name platform  year_of_release   genre  \
# 15833  Strongest Tokyo University Shogi DS       DS             1985  Action
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 15833       0.0       0.0      0.02          0.0           NaN         NaN
#
#       rating  pegi_rating  all_sales
# 15833    NaN          NaN       0.02

# %% [markdown]
# DS не настолько стара (выбилась эта игра при дальнейшем построении графиков)

# %%
df= df.drop(df[(df['year_of_release']==1985)&(df['platform']=='DS')].index)

# %% [markdown]
# ### Вывод

# %% [markdown]
# Суммарные продажи посчитаны, tbd удалено, <font color=red>Игры без указанного года релиза удалены</font>, так же добавил столбец Pegi рейтинга, а вдруг пригодится. заменил тип данных в годе, это помогло в свединии с ПЕГИ. у пользовательского рейтинга заменили тип данных после удаления строкового значения
#
# причины:
#
# Рейтинг - есть игры и до создания ESRB, есть игры Японского рынка, которые не оценивалить американской комиссией, есть непонятные пропуски (выше приводил примеры)
#
# Оценки - тоже отсутствуют у большинства старых игр, это нормально. некоторые вышли до выхода интернета в массы))

# %% [markdown]
# ## Анализ

# %% [markdown]
# ### Продажи по годам,  Количесвто выпущенных игр по годам

# %%
df.describe()
# Out:
#        year_of_release      na_sales      eu_sales      jp_sales  \
# count     16442.000000  16442.000000  16442.000000  16442.000000
# mean       2006.487228      0.264045      0.145948      0.078495
# std           5.873335      0.818422      0.506745      0.311118
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360001     28.959999     10.220000
#
#         other_sales  critic_score   user_score  pegi_rating     all_sales
# count  16442.000000   7982.000000  7462.000000  3450.000000  16442.000000
# mean       0.047599     68.992608     7.126548     9.398551      0.536087
# std        0.188016     13.920049     1.499429     5.845032      1.558871
# min        0.000000     13.000000     0.000000     3.000000      0.000000
# 25%        0.000000     60.000000     6.400000     3.000000      0.060000
# 50%        0.010000     71.000000     7.500000     7.000000      0.170000
# 75%        0.030000     79.000000     8.200000    16.000000      0.470000
# max       10.570000     98.000000     9.700000    18.000000     82.539993

# %%
sales_pivot = df.pivot_table(index = 'year_of_release', values = 'all_sales', aggfunc=['sum', 'count', 'mean'] )
sales_pivot
# Out:
#                         sum     count      mean
#                   all_sales all_sales all_sales
# year_of_release
# 1980              11.380000         9  1.264444
# 1981              35.680000        46  0.775652
# 1982              28.879999        36  0.802222
# 1983              16.799999        17  0.988235
# 1984              50.349998        14  3.596429
# 1985              53.930000        13  4.148462
# 1986              37.079998        21  1.765714
# 1987              21.700001        16  1.356250
# 1988              47.209999        15  3.147333
# 1989              73.449997        17  4.320588
# 1990              49.369999        16  3.085625
# 1991              32.230000        41  0.786098
# 1992              76.159996        43  1.771163
# 1993              45.989998        60  0.766500
# 1994              79.229996       121  0.654793
# 1995              88.120003       219  0.402374
# 1996             199.149994       263  0.757224
# 1997             201.070007       289  0.695744
# 1998             256.309998       379  0.676280
# 1999             251.110001       338  0.742929
# 2000             201.660004       350  0.576171
# 2001             331.459991       482  0.687676
# 2002             394.970001       829  0.476442
# 2003             357.540009       775  0.461342
# 2004             418.679993       762  0.549449
# 2005             457.820007       939  0.487561
# 2006             517.710022      1006  0.514622
# 2007             604.750000      1197  0.505221
# 2008             671.500000      1427  0.470568
# 2009             658.820007      1426  0.462006
# 2010             590.130005      1255  0.470223
# 2011             507.579987      1136  0.446813
# 2012             355.839996       652  0.545767
# 2013             361.239990       544  0.664044
# 2014             331.529999       581  0.570620
# 2015             267.980011       606  0.442211
# 2016             129.940002       502  0.258845

# %%
sales_pivot.plot(xlim=(1980,2017));

# %% [markdown]
# #### Вывод

# %% [markdown]
# Наибольшими продажами на момент 2016 года обладают игры 2008-2010 годов выпуска, количество выпущенных Тайтлов в этих годах так же в топе. Вроде бы и логичная зависимость, но глядя на графики вовсе не прямая. Наклепать игр можно много, финансы у населения не безконечны. Когда то и драться за покупателя придется.

# %% [markdown]
# ### Количесвто выпущенных игр по Платформам

# %%
platform_pivot = df.pivot_table(index = 'platform', values = 'all_sales', aggfunc=['sum', 'count', 'mean']  )
platform_pivot.columns = ('sum', 'count', 'mean')
platform_pivot.sort_values('sum')
# Out:
#                   sum  count      mean
# platform
# PCFX         0.030000      1  0.030000
# GG           0.040000      1  0.040000
# 3DO          0.100000      3  0.033333
# TG16         0.160000      2  0.080000
# WS           1.420000      6  0.236667
# NG           1.440000     12  0.120000
# SCD          1.860000      6  0.310000
# DC          15.950000     52  0.306731
# GEN         28.350000     27  1.050000
# SAT         33.590000    173  0.194162
# PSV         53.810001    429  0.125431
# WiiU        82.190002    147  0.559116
# 2600        86.480003    116  0.745517
# XOne       159.320007    247  0.645020
# GC         196.729996    542  0.362970
# SNES       200.039993    239  0.836987
# N64        218.009995    316  0.689905
# NES        251.050003     98  2.561735
# XB         251.569992    803  0.313288
# GB         254.429993     97  2.622990
# PC         255.759995    957  0.267252
# 3DS        257.809998    512  0.503535
# PSP        289.529999   1193  0.242691
# GBA        312.880005    811  0.385795
# PS4        314.140015    392  0.801378
# PS         727.580017   1190  0.611412
# DS         802.760010   2120  0.378660
# Wii        891.179993   1286  0.692986
# PS3        931.339966   1305  0.713670
# X360       961.239990   1232  0.780227
# PS2       1233.559937   2127  0.579953

# %%
top_list =platform_pivot[platform_pivot['sum']>258].index

# %%
df_top_platforms = df[df['platform'].isin(top_list)]

# %%
df_top_platforms['platform'].unique()
# Out:
# array(['Wii', 'DS', 'X360', 'PS3', 'PS2', 'GBA', 'PS4', 'PS', 'PSP'],
#       dtype=object)

# %%
df_top_platforms_pivot = df_top_platforms.pivot_table(index = ['platform','year_of_release'], values = 'all_sales', aggfunc=['sum', 'count', 'mean'])

# %%
#df_top_platforms_pivot.loc['3DS','sum'].plot()
for index in top_list:
    df_top_platforms_pivot.loc[index,'sum'].plot(title = index )

# %% [markdown]
# Судя по графику суммарных продаж время жизни консоли (пк ут в счет не берем, он в этом смысле вечен) от 6 до 8 лет, можно аналогичное посмотреть по количеству выпущенных игр

# %%
for index in top_list:
    df_top_platforms_pivot.loc[index,'count'].plot(title = index )

# %% [markdown]
# аналогичный резульат

# %%
fig, ax = plt.subplots(figsize=(15,9))

for date, new_df in df_top_platforms_pivot.groupby(level = 0):
    ax.plot(new_df.index.get_level_values('year_of_release').values,
            new_df['sum'],
            label = new_df.index.get_level_values('platform').values[0],
            #marker = 'o-',
            linestyle = '-')

ax.legend(frameon = True)

plt.show()

# %% [markdown]
# Гуглеж по "pandas plot from pivot table multi index" первой ссылкой приводит на пример по моей же сводной таблице. https://stackoverflow.com/questions/68647288/how-to-create-a-plot-for-a-multiindex-dataframe
#
# я не до конца понимаю как это работает но именно к этому я и хотел прийти своими попытками выше.

# %% [markdown]
# #### Вывод

# %% [markdown]
# Судя по графикам средний период активной жизни косноли - от 6 до 8 лет. возьмем далее 7 лет (2010-2016). в топ 10 Все стационарные Соньки, ПСП, одна стационарная Нинтенда и куча портативных, ящик 360.

# %% [markdown]
# ### Анализ актуального периода

# %%
df_act = df[df['year_of_release']>=2010]
df_act.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5276 entries, 14 to 16572
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             5276 non-null   object
#  1   platform         5276 non-null   object
#  2   year_of_release  5276 non-null   int32
#  3   genre            5276 non-null   object
#  4   na_sales         5276 non-null   float32
#  5   eu_sales         5276 non-null   float32
#  6   jp_sales         5276 non-null   float32
#  7   other_sales      5276 non-null   float32
#  8   critic_score     2311 non-null   float64
#  9   user_score       2498 non-null   float64
#  10  rating           3112 non-null   object
#  11  pegi_rating      1583 non-null   float32
#  12  all_sales        5276 non-null   float32
# dtypes: float32(6), float64(2), int32(1), object(4)
# memory usage: 432.8+ KB

# %%
df_act_pivot = df_act.pivot_table(index = ['platform','year_of_release'], values = 'all_sales', aggfunc=['sum', 'count', 'mean'])

# %%
df_act_pivot
# Out:
#                                 sum     count      mean
#                           all_sales all_sales all_sales
# platform year_of_release
# 3DS      2011             63.199997       116  0.544828
#          2012             51.360001        93  0.552258
#          2013             56.570000        91  0.621648
#          2014             43.759998        80  0.547000
#          2015             27.780001        86  0.323023
# ...                             ...       ...       ...
# X360     2016              1.520000        13  0.116923
# XOne     2013             18.960001        19  0.997895
#          2014             54.070000        61  0.886393
#          2015             60.139999        80  0.751750
#          2016             26.150000        87  0.300575
#
# [65 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(12,10))

for date, new_df in df_act_pivot.groupby(level = 0):
    ax.plot(new_df.index.get_level_values('year_of_release').values,
            new_df['sum'],
            label = new_df.index.get_level_values('platform').values[0],
            #marker = 'o-',
            linestyle = '-')

ax.legend(frameon = True)

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# А вот тут прям все идеально.
# </div>

# %% [markdown]
# итак, 2016 год не полный, так что смотрим до 2015го. рост только у XBOX ONE и PS4, Спад, но все же значимые продажи у wiiU, ps3, xbox360 и nintendi 3ds (правда последние 2 я на графике по цвету различить не могу:), но по 3ds данные только с 11 года)
#
# Важное Но - в таблице указаны продажи игры с момента ее выхода до текущего времени. то есть если игра вышла в конце 2012, а все продаже собрала в 2013, то данные попадут в 2012.

# %%
df_act[df_act['platform']=='PS4']['all_sales'].plot(kind = 'box', ylim=(0,2))
# Out:
# <AxesSubplot:>

# %%
for plat in df_act['platform'].unique():
    df_act[df_act['platform']==plat]['all_sales'].plot(kind = 'box', ylim=(0,2), title = plat)
    plt.show()

# %% [markdown]
# да, график с усами по каждой платформе. но не наглядно

# %%
df_act.boxplot(column='all_sales', by = 'platform', figsize=(15,10))
plt.ylim([0, 3])
# Out:
# (0.0, 3.0)

# %% [markdown]
# это называется "читаем инструкцию, а не stackoverflow". как изменить диапазон шкалы y я не нашел.

# %% [markdown]
# #### вывод по "ящику"

# %% [markdown]
# Выбросы Есть. Вот только  сбрасывать их со счетов нельзя. это игры-Хиты.

# %% [markdown]
# ### зависимость продаж от оценок пользователей и критиков

# %% [markdown]
# выберем платформу X360

# %%
platf = 'X360'

# %%
df_act[df_act['platform']==platf].plot(x='critic_score', y='all_sales', kind='scatter', figsize=(15,9), ylim=(0,5))
df_act[df_act['platform']==platf].plot(x='user_score', y='all_sales', kind='scatter', figsize=(15,9), ylim=(0,5));

# %% [markdown]
# посмотрим по другим платформам

# %%
platf = 'PS3'

# %%
df_act[df_act['platform']==platf].plot(x='critic_score', y='all_sales', kind='scatter', figsize=(15,9), ylim=(0,5))
df_act[df_act['platform']==platf].plot(x='user_score', y='all_sales', kind='scatter', figsize=(15,9), ylim=(0,5));

# %%
platf = 'PS4'

# %%
df_act[df_act['platform']==platf].plot(x='critic_score', y='all_sales', kind='scatter', figsize=(15,9), ylim=(0,5))
df_act[df_act['platform']==platf].plot(x='user_score', y='all_sales', kind='scatter', figsize=(15,9), ylim=(0,5));

# %%
platf = 'XOne'

# %%
df_act[df_act['platform']==platf].plot(x='critic_score', y='all_sales', kind='scatter', figsize=(15,9), ylim=(0,5))
df_act[df_act['platform']==platf].plot(x='user_score', y='all_sales', kind='scatter', figsize=(15,9), ylim=(0,5));

# %% [markdown]
# #### вывод

# %% [markdown]
# диаграммы рассеяния выглядят похоже (самые выдающиеся продажи я отрезал). по Xbox360 и ps3 больше данных, график выглядит более плотным. (что логично, это более старые консоли), корреляция положительная для всеъ графиков

# %% [markdown]
# ### Зависимость продаж от жанров

# %%
df_act.boxplot(column='all_sales', by = 'genre', figsize=(15,10));

# %% [markdown]
# #### Вывод

# %% [markdown]
# Если говорить о средненькой игре, то наиболее результативные жанры это Шутеры, Платформеры и спорт. но если речь идет о потенциальном Хите, выбивающемся из статистики, то в платформеры лезть не стоит, лучше Ролевые рассмотреть. Пазлы и приключения в провале

# %% [markdown]
# ## Анализ по региаонам продаж

# %% [markdown]
# ### Платформы

# %%
df_act.groupby('platform')['na_sales'].sum().sort_values()
# Out:
# platform
# PS2       2.320000
# PSP       9.650000
# PSV      12.470000
# WiiU     38.099998
# PC       39.070000
# DS       59.660000
# 3DS      82.650002
# XOne     93.120003
# PS4     108.739998
# Wii     121.199997
# PS3     229.250000
# X360    334.179993
# Name: na_sales, dtype: float32

# %%
df_act.groupby('platform')['eu_sales'].sum().sort_values()
# Out:
# platform
# PS2       1.670000
# PSP       7.590000
# PSV      13.070000
# WiiU     25.129999
# DS       28.059999
# XOne     51.590000
# 3DS      61.270000
# Wii      65.909996
# PC       68.820000
# PS4     141.089996
# X360    163.410004
# PS3     213.600006
# Name: eu_sales, dtype: float32

# %%
df_act.groupby('platform')['jp_sales'].sum().sort_values()
# Out:
# platform
# PC        0.000000
# XOne      0.340000
# PS2       0.800000
# X360      5.460000
# WiiU     13.010000
# PS4      15.960000
# Wii      17.750000
# PSV      21.840000
# DS       27.900000
# PSP      42.200001
# PS3      59.259998
# 3DS     100.620003
# Name: jp_sales, dtype: float32

# %% [markdown]
# #### вывод

# %% [markdown]
# Америка - в топе только стационарныы консоли. в Европе в топ 5 попал обычный PC и вообще не попали консоли нового поколения (ps4 и xone), предположил, что это может быть вызвано более поздним запуском в европе, но нет. релиз и соньки и ящика на обоих континетах в один день.
#
# Япония - отдельный мир. из стационарных в топе только PS3, все остальное - портативные консоли.

# %% [markdown]
# ### Жанры

# %%
df_act.groupby('genre')['na_sales'].sum().sort_values()
# Out:
# genre
# Puzzle            9.100000
# Strategy         13.250000
# Adventure        20.840000
# Simulation       26.389999
# Fighting         39.049999
# Racing           46.110001
# Platform         54.900002
# Role-Playing    112.050003
# Misc            123.800003
# Sports          156.809998
# Shooter         237.470001
# Action          290.640015
# Name: na_sales, dtype: float32

# %%
df_act.groupby('genre')['eu_sales'].sum().sort_values()
# Out:
# genre
# Puzzle            6.580000
# Strategy         12.490000
# Adventure        18.879999
# Fighting         20.330000
# Simulation       26.389999
# Platform         38.299999
# Racing           54.750000
# Misc             66.089996
# Role-Playing     75.480003
# Sports          116.839996
# Shooter         171.449997
# Action          233.630005
# Name: eu_sales, dtype: float32

# %%
df_act.groupby('genre')['jp_sales'].sum().sort_values()
# Out:
# genre
# Puzzle            3.400000
# Racing            6.680000
# Strategy          6.800000
# Simulation       13.300000
# Fighting         13.900000
# Shooter          14.040000
# Sports           15.510000
# Adventure        15.670000
# Platform         15.810000
# Misc             24.290001
# Action           72.199997
# Role-Playing    103.540001
# Name: jp_sales, dtype: float32

# %% [markdown]
# #### вывод

# %% [markdown]
# Америка и Европа - почти под копирку.
#
# Япония - в топе Ролевухи, да и вообще все то, что в европе и америке не популярно.

# %% [markdown]
# ### Влияние рейтинга ESRB

# %% [markdown]
# рассмотрим гистограммами рассеяния

# %%
df_act[~df_act['rating'].isna()].plot(x='rating', y='na_sales', kind='scatter', figsize=(15,9), ylim=(0,5), alpha =0.05);

# %%
df_act[~df_act['rating'].isna()].plot(x='rating', y='eu_sales', kind='scatter', figsize=(15,9), ylim=(0,5), alpha =0.05);

# %%
df_act[~df_act['rating'].isna()].plot(x='rating', y='jp_sales', kind='scatter', figsize=(15,9), ylim=(0,5), alpha =0.05);

# %% [markdown]
# #### Вывод

# %% [markdown]
# В Японии и Европе M и T рейтинги неного преобладают в плотности. в абсолютныъ значениях в пики выбивается E, что вполне логично - игры для всех, нет ограничений по продаже и рекламе. Кстати нет рейтинга А (игры с которым вроде как к рекламе даже запрещены)

# %% [markdown]
# ### Pegi

# %% [markdown]
# Ну и раз уж я потратил тучу времени на вклинивание сюда датесета с Пэги рейтингом, то рассмотрим и его

# %%
df_act[~df_act['pegi_rating'].isna()].plot(x='pegi_rating', y='na_sales', kind='scatter', figsize=(15,9), ylim=(0,5), alpha =0.05);

# %%
df_act[~df_act['pegi_rating'].isna()].plot(x='pegi_rating', y='eu_sales', kind='scatter', figsize=(15,9), ylim=(0,5), alpha =0.05);

# %%
df_act[~df_act['pegi_rating'].isna()].plot(x='pegi_rating', y='jp_sales', kind='scatter', figsize=(15,9), ylim=(0,5), alpha =0.05);

# %% [markdown]
# #### вывод

# %% [markdown]
# 0+ преобладает, а следом 16+ и 18+

# %% [markdown]
# ## проверка гипотез

# %% [markdown]
# ### Средние пользовательские рейтинги платформ Xbox One и PC одинаковые

# %% [markdown]
# H0: Средние Рейтинги равны
#
# H1: Средние Рейтинги НЕ равны
#
# alpha = 0.05 - примем так

# %%
results = st.ttest_ind(
    df_act[(df_act['platform']=='PC')&(~df_act['user_score'].isna())]['user_score'], 
    df_act[(df_act['platform']=='XOne')&(~df_act['user_score'].isna())]['user_score'])
results.pvalue
# Out:
# 0.980998110649032

# %% [markdown]
# #### вывод

# %% [markdown]
# Гипотезе НЕ отвергнута

# %% [markdown]
# ### Средние пользовательские рейтинги жанров Action и Sports разные

# %% [markdown]
# H0: Средние Рейтинги равны
#
# H1: Средние Рейтинги НЕ равны
#
# alpha = 0.05 - примем так

# %%
results = st.ttest_ind(
    df_act[(df_act['genre']=='Action')&(~df_act['user_score'].isna())]['user_score'], 
    df_act[(df_act['genre']=='Sports')&(~df_act['user_score'].isna())]['user_score'])
results.pvalue
# Out:
# 9.881792320848471e-19

# %% [markdown]
# #### вывод

# %% [markdown]
# Гипотезе отвергнута. проверяась гипотеза равенства, так как так работает метод. проверяет равенство.

# %% [markdown]
# ## Общий Вывод

# %% [markdown]
# Ознакомившись с датасетом можно дать следующие рекомендации:
#
# В Америке лучшим спросом пользуются игры стационарных консолей. в Европе не стоит забывать про ПК. в Японии преобладают портативные консоли. Так же учитывать популярность Жанров, рассмотренную в пункте 4.2. Япония все-таки специфичный рынок. в качестве рейтинга все же видится более удачным подростковый и взрослый (M и T), так как кого это останавливало (в 7 лет играть в Мортал комбат с рейтингом М - норма:), а так же тот, кто для нее сейчас "мал", через пару годков может дорасти до нее и стать покупателем.
